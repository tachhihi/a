# %% [markdown]
# # MoneyPrinterTurbo Setup Guide
#
# This notebook will guide you through the process of setting up [MoneyPrinterTurbo](https://github.com/harry0703/MoneyPrinterTurbo).

# %% [markdown]
# ## 1. Clone Repository and Install Dependencies
#
# First, we'll clone the repository from GitHub and install all required packages:

# %%
# !git clone https://github.com/harry0703/MoneyPrinterTurbo.git
# %cd MoneyPrinterTurbo
# !pip install -q uv pyngrok
# !uv python install 3.11
# Colab 预装了 google-colab / google-genai / google-adk 等包，直接 pip install -r requirements.txt
# 会覆盖全局依赖并触发版本冲突。这里使用 uv 为项目创建独立 .venv，避免影响 Colab 运行时。
# !uv sync --frozen --python 3.11
# Out:
# fatal: destination path 'MoneyPrinterTurbo' already exists and is not an empty directory.
# /content/MoneyPrinterTurbo/MoneyPrinterTurbo
# Python 3.11 is already installed
# Checked 123 packages in 9ms

# %% [markdown]
# ## 2. Configure ngrok for Remote Access
#
# We'll use ngrok to create a secure tunnel to expose our local Streamlit server to the internet.
#
# **Important**: You need to get your authentication token from the [ngrok dashboard](https://dashboard.ngrok.com/get-started/your-authtoken) to use this service.

# %%
# %cd /content/MoneyPrinterTurbo

# !cp -n config.example.toml config.toml
# !pkill -f "streamlit run" || true

import subprocess, time
from google.colab import output

subprocess.Popen([
    "uv", "run", "streamlit", "run", "webui/Main.py",
    "--server.port", "8501",
    "--server.address", "0.0.0.0",
    "--server.headless", "true",
    "--server.enableCORS", "false",
    "--server.enableXsrfProtection", "false",
], stdout=open("streamlit.log", "w"), stderr=subprocess.STDOUT)

time.sleep(10)

output.serve_kernel_port_as_window(8501)
# Out:
# /content/MoneyPrinterTurbo
# ^C
# Warning: This function may stop working due to changes in browser security.
# Try `serve_kernel_port_as_iframe` instead.

# %% [markdown]
# ## 3. Launch Application and Generate Public URL
#
# Now we'll start the Streamlit server and create an ngrok tunnel to make it accessible online:

# %%
import subprocess
import time

print("🚀 Starting MoneyPrinterTurbo...")
# 通过 uv run 进入项目 .venv，确保 Streamlit 使用上一步锁定的依赖版本。
streamlit_proc = subprocess.Popen([
    "uv", "run", "streamlit", "run", "./webui/Main.py", "--server.port=8501", "--server.address=0.0.0.0"
])

# Wait for the server to initialize
time.sleep(5)

print("🌐 Creating ngrok tunnel to expose the MoneyPrinterTurbo...")
public_url = ngrok.connect(8501, bind_tls=True)

print("✅ Deployment complete! Access your MoneyPrinterTurbo at:")
print(public_url)
# Out:
# 🚀 Starting MoneyPrinterTurbo...
# 🌐 Creating ngrok tunnel to expose the MoneyPrinterTurbo...
# ERROR:pyngrok.process.ngrok:t=2026-06-28T07:23:23+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: your_ngrok_auth_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-06-28T07:23:23+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: your_ngrok_auth_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-06-28T07:23:23+0000 lvl=eror msg="terminating with error" obj=app err="authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: your_ngrok_auth_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n"
# ---------------------------------------------------------------------------
# PyngrokNgrokError                         Traceback (most recent call last)
# /tmp/ipykernel_2606/3685603385.py in <cell line: 0>()
#      12
#      13 print("🌐 Creating ngrok tunnel to expose the MoneyPrinterTurbo...")
# ---> 14 public_url = ngrok.connect(8501, bind_tls=True)
#      15
#      16 print("✅ Deployment complete! Access your MoneyPrinterTurbo at:")
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in connect(addr, proto, name, pyngrok_config, **options)
#     387     logger.info(f"Opening tunnel named: {name}")
#     388
# --> 389     api_url = get_ngrok_process(pyngrok_config).api_url
#     390
#     391     logger.debug(f"Creating tunnel with options: {options}")
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/ngrok.py in get_ngrok_process(pyngrok_config)
#     215     install_ngrok(pyngrok_config)
#     216
# --> 217     return process.get_process(pyngrok_config)
#     218
#     219
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/process.py in get_process(pyngrok_config)
#     271         return _current_processes[pyngrok_config.ngrok_path]
#     272
# --> 273     return _start_process(pyngrok_config)
#     274
#     275
#
# /usr/local/lib/python3.12/dist-packages/pyngrok/process.py in _start_process(pyngrok_config)
#     447
#     448         if ngrok_process.startup_error is not None:
# --> 449             raise PyngrokNgrokError(f"The ngrok process errored on start: {ngrok_process.startup_error}.",
#     450                                     ngrok_process.logs,
#     451                                     ngrok_process.startup_error)
#
# PyngrokNgrokError: The ngrok process errored on start: authentication failed: The authtoken you specified does not look like a proper ngrok authtoken.\nYour authtoken: your_ngrok_auth_token\nInstructions to install your authtoken are on your ngrok dashboard:\nhttps://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_105\r\n.
